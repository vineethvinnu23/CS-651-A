# %% [markdown]
# # CS-651-A TEXT BASED ANALYSIS
# # Vineeth Anumula
# # Classwork - 2

# %% [markdown]
#  # Read the csv file
#     The below CSV file is related to UN General Debates, which often contain data about speeches or statements made at the United Nations General Assembly. In the following steps we perform data cleaning then some of the visualizations.

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\tsaiv\OneDrive\Desktop/un-general-debates-blueprint.csv")
df.head(20)
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# ...

# %% [markdown]
# To get the column names

# %%
df.columns
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %% [markdown]
# Get the datatypes for each column

# %%
df.dtypes
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %% [markdown]
# The describe() function is used to generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution.

# %%
df.describe()
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %% [markdown]
# To add a new column with the length of the “text” column

# %%
df['length'] = df['text'].str.len()
df.describe()
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %% [markdown]
# To provide stats about text fields

# %%
df.describe(include='O')
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %% [markdown]
# To check for missing data

# %%
df.isna().sum()
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# #### To fill 'unknown' in place of empty spots

# %%
df['speaker'].fillna('unknown', inplace=True)
df['position'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %% [markdown]
# To convert string to uppercase letters

# %%
df['speaker']= df['speaker'].str.upper()
df['position'] = df['position'].str.upper()
df['text'] = df['text'].str.upper()
df
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            MR. NAS
# 1          25  1970     ARG     Argentina                 MR. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        MR. MCMAHON
# 3          25  1970     AUT       Austria                 MR. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         MR. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
# ...

# %% [markdown]
# #### To print the speakers with ‘BUSH’ in them

# %%
df[df['speaker'].str.contains('BUSH')]
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                BUSH  PRESIDENT
# 2876       45  1990     USA  United States         GEORGE BUSH    UNKNOWN
# 3038       46  1991     USA  United States         GEORGE BUSH  PRESIDENT
# 3207       47  1992     USA  United States     MR. GEORGE BUSH  PRESIDENT
# 4814       56  2001     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5002       57  2002     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5191       58  2003     USA  United States      GEORGE W. BUSH  PRESIDENT
# 5382       59  2004     USA  United States   MR. GEORGE W BUSH  PRESIDENT
# 5760       61  2006     USA  United States  MR. GEORGE W. BUSH  PRESIDENT
# 5951       62  2007     USA  United States      GEORGE W. BUSH  PRESIDENT
# 6143       63  2008     USA  United States      GEORGE W. BUSH  PRESIDENT
#
#                                                    text  length
# ...

# %% [markdown]
# ## Visualization graphs
# This code creates a line plot of the data in the column 'length'. A line plot is useful for visualizing the change in a variable over time or in sequence. It connects data points with a continuous line, making it easy to see trends, fluctuations, and patterns.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# For the line plot
df['length'].plot()
plt.show()

# %% [markdown]
# ##### This code generates a box plot with the orientation set to horizontal (vert=False). This box plot provides a graphical representation of the central tendency and variability of the data. It shows the median, quartiles, and possible outliers.

# %%
# For the horizontal box plot
df['length'].plot(kind='box', vert=False)
plt.show()  # To display the plot

# %% [markdown]
# ##### The plotted histogram is used to represent the distribution of numerical data by dividing the data into bins or intervals and counting the number of observations in each bin.

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ##### The code snippet is to create a box plot for the 'length' column, filtered by specific countries.

# %%
import seaborn as sns 
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(8, 6)

# %% [markdown]
# The provided function tokenize is a Python function that uses the regex module to find and return all the word-like substrings in the input text.

# %%
import regex as re
def tokenize(column):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %% [markdown]
# Sample text to perform tokenize function

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', 'www', 'cdc', 'gov']

# %% [markdown]
# ###### To perform stop words We will use the list of English stop words that are standard in python

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'own', 'itself', 'd', 'who', 'been', 'your', 're', 'y', "she's", 'against', 'both', "you're", 've', 'very', 'in', 'out', 'again', "mightn't", 'if', 'herself', 'so', 'yourself', 'does', 'after', 'this', 'during', 'here', 'than', 'these', 'mightn', 'or', 'those', "didn't", 'have', 'shouldn', 'between', 'more', 'theirs', 'them', 'it', 'doesn', 'not', 'were', 'ours', 'do', 'be', 'while', "wasn't", 'hasn', 'ourselves', 'nor', "shan't", 't', 'shan', 'from', "you'll", 'now', 'and', 'won', "aren't", 'yours', 'wasn', 'most', 'himself', 'his', 'what', 'only', "won't", 'off', 'on', 'myself', 'some', 'are', 'she', 'will', "mustn't", 'which', 'weren', 'haven', 'all', 'being', "it's", 'above', 'hers', 'mustn', "doesn't", 'had', 'as', 'didn', 'where', 'aren', 'such', 'ma', 'was', "should've", "haven't", 'her', 'no', 'below', 's', 'until', 'ain', 'is', 'down', 'he', 'whom', "hadn't", 'the', 'him', 'by', 'themselves', "wouldn't", 'me', 'with', 'they', 'to', 'because', 'their', 'll', 'couldn', 'would
# ...

# %% [markdown]
# #### Function to remove stop words

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
# Out:
# ['Let', 'defeat', 'SARS-CoV-2', 'together', 'www', 'cdc', 'gov']

# %% [markdown]
# ### Creating a pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ### Code to run the pipeline

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ### Program to Count the tokens and to print last 5 rows in dataset

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  MR. ABDRABUH MANSOUR HADI MANSOUR
# 7503       70  2015     YUG    Yugoslavia               MR. TOMISLAV NIKOLIĆ
# 7504       70  2015     ZAF  South Africa                         JACOB ZUMA
# 7505       70  2015     ZMB        Zambia             MR. EDGAR CHAGWA LUNGU
# 7506       70  2015     ZWE      Zimbabwe                      ROBERT MUGABE
#
#        position                                               text  length  \
# 7502  PRESIDENT  ON BEHALF OF THE PEOPLE AND THE GOVERNMENT OF ...   10568
# 7503  PRESIDENT  \nSEVENTY YEARS HAVE PASSED SINCE THE ESTABLIS...   25430
# 7504  PRESIDENT  I SHOULD LIKE TO CONGRATULATE THE PRESIDENT AN...   13662
# 7505  PRESIDENT  I WOULD LIKE TO BEGIN BY THANKING THE SECRETAR...   14247
# 7506  PRESIDENT  ALLOW ME AT THE OUTSET TO EXTEND TO MR. MOGENS...   11013
#
# ...

# %% [markdown]
# ###### using the counter method to count the words

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
#  ###### add new data to the current count

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ###### counting the most common elements

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('nations', 24828), ('united', 24225), ('international', 23324), ('world', 18215), ('countries', 16689)]

# %% [markdown]
# ###### Now we put the word frequency in it’s own dataframe for analysis

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %% [markdown]
# ###### Sort and display

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#                 freq
# token
# nations        24828
# united         24225
# international  23324
# world          18215
# countries      16689
# peace          14205
# development    12473
# states         12140
# people         11698
# security       11375

# %% [markdown]
# ### Code to describe the data

# %%
freq_df.describe()
# Out:
#                freq
# count  35797.000000
# mean      61.650390
# std      422.813421
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%       15.000000
# max    24828.000000

# %% [markdown]
# ### Bar chart between frequency and token

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### program to print Word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("year==2015 and country=='USA'")['text'].values[0]

plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# #### Another example for word cloud

# %%
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
