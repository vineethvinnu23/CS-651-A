# %% [markdown]
# ## Vineeth Anumula
# ## Assignment - 5

# %% [markdown]
# ## SENTIMENTAL ANALYSIS

# %% [markdown]
# **LOADING THE DATA**

# %%
#LOADING THE DATASET
import pandas as pd 
df = pd.read_csv('sentimentdataset.csv')
df.sample(10)
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 336           337         341
# 394           395         399
# 720           721         725
# 490           491         495
# 444           445         449
# 425           426         430
# 4               4           4
# 584           585         589
# 368           369         373
# 682           683         687
#
#                                                   Text        Sentiment  \
# 336  Calmness found in the rhythm of raindrops on t...   Calmness
# 394  Soaring like a free spirit on the winds of a c...   Freedom
# 720  Attending a school talent show to support clas...           Happy
# 490  Standing before the grandeur of the Eiffel Tow...      Reflection
# 444  The bitterness of betrayal, a taste that linge...      Bitterness
# 425  Aching heart, the symphony of pain plays in th...       Suffering
# 4     Trying out a new recipe for dinner tonight.  ...       Neutral
# 584  Decided to study for exams but ended up making...        Surprise
# 368  Elation over discovering a rare book in a quai...   Elation
# 682  Trying out a new smoothie recipe for a healthy...      Excitement
#
#                Timestamp                             User     Platform  \
# 336  2017-11-08 21:20:00                  RainWatcher        Twitter
# 394  2021-02-28 13:00:00                 CoastalExplorer     Twitter
# 720  2023-10-18 16:45:00     TalentShowSupportHighSchool     Facebook
# 490  2018-05-12 17:30:00                    ParisDreamer      Twitter
# 444  2019-10-22 17:00:00                   PalateStainer    Instagram
# 425  2022-03-20 19:30:00                 SilentSufferer      Facebook
# 4    2023-01-15 19:55:00                    ChefCook        Instagram
# 584  2023-05-24 13:15:00                     MemeCreator    Instagram
# 368  2018-09-22 16:30:00                 Bookworm           Instagram
# 682  2023-09-10 20:45:00   SmoothieConnoisseurHighSchool    Instagram
#
#                                           Hashtags  Retweets  Likes  \
# 336   #Calmness #RainyDays                              18.0   35.0
# 394       #Freedom #CoastalAdventure                    30.0   60.0
# 720          #TalentShow #HighSchoolEntertainment       19.0   38.0
# 490                   #Reflection #ParisianDreams       28.0   55.0
# 444                     #Bitterness #StainedTrust       15.0   30.0
# 425        #Suffering #HeartacheSymphony                25.0   50.0
# 4        #Cooking #Food                                 12.0   25.0
# 584                      #StudyingMemes #TeenLife       25.0   50.0
# 368      #Elation #RareBookDiscovery                    40.0   80.0
# 682            #HealthyLiving #HighSchoolWellness       23.0   42.0
#
#                   Country  Year  Month  Day  Hour
# 336   Australia            2017     11    8    21
# 394    Australia           2021      2   28    13
# 720                Canada  2023     10   18    16
# 490               France   2018      5   12    17
# 444              Germany   2019     10   22    17
# 425      Brazil            2022      3   20    19
# 4              Australia   2023      1   15    19
# 584                Canada  2023      5   24    13
# 368    USA                 2018      9   22    16
# 682                    UK  2023      9   10    20

# %% [markdown]
# **GET THE BING LIU LEXICON**

# %%
#Downloading the opinion lexicon
from sklearn import preprocessing
import nltk
#nltk.download('opinion_lexicon')
from nltk.corpus import opinion_lexicon
from nltk.tokenize import word_tokenize
print('Total number of words in opinion lexicon', len(opinion_lexicon.words()))
print('Examples of positive words in opinion lexicon',
opinion_lexicon.positive()[:10])
print('Examples of negative words in opinion lexicon',
opinion_lexicon.negative()[:10])
# Out:
# Total number of words in opinion lexicon 6789
# Examples of positive words in opinion lexicon ['a+', 'abound', 'abounds', 'abundance', 'abundant', 'accessable', 'accessible', 'acclaim', 'acclaimed', 'acclamation']
# Examples of negative words in opinion lexicon ['2-faced', '2-faces', 'abnormal', 'abolish', 'abominable', 'abominably', 'abominate', 'abomination', 'abort', 'aborted']

# %% [markdown]
# **CREATING THE 'DICTIONARY'**

# %%
# Let's create a dictionary which we can use for scoring our review text
nltk.download('punkt')
df.rename(columns={"reviewText": "text"}, inplace=True)
pos_score = 1
neg_score = -1
word_dict = {}

# Adding the positive words to the dictionary
for word in opinion_lexicon.positive():
     word_dict[word] = pos_score

# Adding the negative words to the dictionary
for word in opinion_lexicon.negative():
     word_dict[word] = neg_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/b37e750d-630d-4bcf-a122-
# [nltk_data]     bb3a4a582eb9/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **FUNCTION TO DO THE MATH**

# %%
#function to do the math
def bing_liu_score(text):
    sentiment_score = 0
    bag_of_words = word_tokenize(text.lower())
    for word in bag_of_words:
        if word in word_dict:
            sentiment_score += word_dict[word]
            return sentiment_score

# %% [markdown]
# **CALLING THE FUNCTION**

# %%
#calling the function
df['Text'].fillna('no review', inplace=True)
df['Bing_Liu_Score'] = df['Text'].apply(bing_liu_score)

# %%
df[['Sentiment',"Text", 'Bing_Liu_Score']].head(10)
# Out:
#      Sentiment                                               Text  \
# 0   Positive     Enjoying a beautiful day at the park!        ...
# 1   Negative     Traffic was terrible this morning.           ...
# 2   Positive     Just finished an amazing workout! 💪          ...
# 3   Positive     Excited about the upcoming weekend getaway!  ...
# 4   Neutral      Trying out a new recipe for dinner tonight.  ...
# 5   Positive     Feeling grateful for the little things in lif...
# 6   Positive     Rainy days call for cozy blankets and hot coc...
# 7   Positive     The new movie release is a must-watch!       ...
# 8   Negative     Political discussions heating up on the timel...
# 9   Neutral      Missing summer vibes and beach days.         ...
#
#    Bing_Liu_Score
# 0             1.0
# 1            -1.0
# 2             1.0
# 3             1.0
# 4             NaN
# 5             1.0
# 6             1.0
# 7             NaN
# 8             NaN
# 9             NaN

# %% [markdown]
# **SENTIMENT COUNT**

# %%
#pverall rating
df.groupby('Sentiment').agg({'Bing_Liu_Score':'mean'})
# Out:
#                    Bing_Liu_Score
# Sentiment
#  Acceptance                   1.0
#  Acceptance                  -0.5
#  Accomplishment               1.0
#  Admiration                   1.0
#  Admiration                   1.0
# ...                           ...
#  Wonder                       1.0
#  Wonder                       NaN
#  Wonderment                   1.0
#  Yearning                     1.0
#  Zest                         1.0
#
# [279 rows x 1 columns]
